# %%
from fractions import Fraction

# %%
# Question 1: Add 1/2 and 1/4
print("Answer 1 =", Fraction(1, 2) + Fraction(1, 4))
# Out:
# Answer 1 = 3/4

# %%
# Question 2: Add 2/3 and 1/3
print("Answer 2 =", Fraction(2, 3) + Fraction(1, 3))
# Out:
# Answer 2 = 1

# %%
# Question 3: Subtract 1/5 from 4/5
print("Answer 3 =", Fraction(4, 5) - Fraction(1, 5))
# Out:
# Answer 3 = 3/5

# %%
# Question 4: Multiply 2/3 and 3/4
print("Answer 4 =", Fraction(2, 3) * Fraction(3, 4))
# Out:
# Answer 4 = 1/2

# %%
# Question 5: Divide 3/4 by 1/2
print("Answer 5 =", Fraction(3, 4) / Fraction(1, 2))
# Out:
# Answer 5 = 3/2

# %%
# Question 6: Add 5/8 and 1/8
print("Answer 6 =", Fraction(5, 8) + Fraction(1, 8))
# Out:
# Answer 6 = 3/4

# %%
# Question 7: Subtract 2/7 from 6/7
print("Answer 7 =", Fraction(6, 7) - Fraction(2, 7))
# Out:
# Answer 7 = 4/7
