# %%
import math

# %%
# Question 1: Find the HCF of 12 and 18
a = 12
b = 18
print("Answer 1 =", math.gcd(a, b))
# Out:
# Answer 1 = 6

# %%
# Question 2: Find the HCF of 20 and 30
a = 20
b = 30
print("Answer 2 =", math.gcd(a, b))
# Out:
# Answer 2 = 10

# %%
a = 24
b = 36
print("Answer 3 =", math.gcd(a, b))
# Out:
# Answer 3 = 12

# %%
# Question 4: Find the HCF of 28 and 42
a = 28
b = 42
print("Answer 4 =", math.gcd(a, b))
# Out:
# Answer 4 = 14

# %%
# Question 5: Find the HCF of 45 and 60
a = 45
b = 60
print("Answer 5 =", math.gcd(a, b))
# Out:
# Answer 5 = 15

# %%
# Question 6: Find the HCF of 56 and 98
a = 56
b = 98
print("Answer 6 =", math.gcd(a, b))
# Out:
# Answer 6 = 14

# %%
# Question 7: Find the HCF of 72 and 120
a = 72
b = 120
print("Answer 7 =", math.gcd(a, b))
# Out:
# Answer 7 = 24

# %%
# Question 8: Find the HCF of 81 and 108
a = 81
b = 108
print("Answer 8 =", math.gcd(a, b))
# Out:
# Answer 8 = 27

# %%
# Question 9: Find the HCF of 96 and 144
a = 96
b = 144
print("Answer 9 =", math.gcd(a, b))
# Out:
# Answer 9 = 48

# %%
# Question 10: Find the HCF of 100 and 250
a = 100
b = 250
print("Answer 10 =", math.gcd(a, b))
# Out:
# Answer 10 = 50
