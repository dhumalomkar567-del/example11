# %%
# Question 1: Find the ratio of 10 and 20
a = 10
b = 20
print("Answer 1 =", f"{a}:{b}")
# Out:
# Answer 1 = 10:20

# %%
# Question 2: Find the ratio of 15 and 25
a = 15
b = 25
print("Answer 2 =", f"{a}:{b}")
# Out:
# Answer 2 = 15:25

# %%
# Question 3: Find the ratio of 12 and 18
a = 12
b = 18
print("Answer 3 =", f"{a}:{b}")
# Out:
# Answer 3 = 12:18

# %%
# Question 4: Find the ratio of 8 and 24
a = 8
b = 24
print("Answer 4 =", f"{a}:{b}")
# Out:
# Answer 4 = 8:24

# %%
# Question 5: Find the ratio of 35 and 49
a = 35
b = 49
print("Answer 5 =", f"{a}:{b}")
# Out:
# Answer 5 = 35:49

# %%
# Question 6: Find the simplified ratio of 16 and 20
a = 16
b = 20
gcd = 4
print("Answer 6 =", f"{a//gcd}:{b//gcd}")
# Out:
# Answer 6 = 4:5

# %%
# Question 7: Find the simplified ratio of 21 and 28
a = 21
b = 28
gcd = 7
print("Answer 7 =", f"{a//gcd}:{b//gcd}")
# Out:
# Answer 7 = 3:4

# %%
# Question 8: Find the simplified ratio of 45 and 60
a = 45
b = 60
gcd = 15
print("Answer 8 =", f"{a//gcd}:{b//gcd}")
# Out:
# Answer 8 = 3:4

# %%
# Question 9: Find the simplified ratio of 24 and 36
a = 24
b = 36
gcd = 12
print("Answer 9 =", f"{a//gcd}:{b//gcd}")
# Out:
# Answer 9 = 2:3

# %%
# Question 10: Find the simplified ratio of 50 and 100
a = 50
b = 100
gcd = 50
print("Answer 10 =", f"{a//gcd}:{b//gcd}")
# Out:
# Answer 10 = 1:2
