# %%
# Question 1: Find the average of 10, 20 and 30
a = 10
b = 20
c = 30
print("Answer 1 =", (a + b + c) / 3)
# Out:
# Answer 1 = 20.0

# %%
# Question 2: Find the average of 15, 25 and 35
a = 15
b = 25
c = 35
print("Answer 2 =", (a + b + c) / 3)
# Out:
# Answer 2 = 25.0

# %%
# Question 3: Find the average of 40, 50 and 60
a = 40
b = 50
c = 60
print("Answer 3 =", (a + b + c) / 3)
# Out:
# Answer 3 = 50.0

# %%
# Question 4: Find the average of 12, 18 and 24
a = 12
b = 18
c = 24
print("Answer 4 =", (a + b + c) / 3)
# Out:
# Answer 4 = 18.0

# %%
# Question 5: Find the average of 25, 35 and 45
a = 25
b = 35
c = 45
print("Answer 5 =", (a + b + c) / 3)
# Out:
# Answer 5 = 35.0

# %%
# Question 6: Find the average of 100, 200 and 300
a = 100
b = 200
c = 300
print("Answer 6 =", (a + b + c) / 3)
# Out:
# Answer 6 = 200.0

# %%
# Question 7: Find the average of 8, 16 and 24
a = 8
b = 16
c = 24
print("Answer 7 =", (a + b + c) / 3)
# Out:
# Answer 7 = 16.0

# %%
# Question 8: Find the average of 50, 70 and 90
a = 50
b = 70
c = 90
print("Answer 8 =", (a + b + c) / 3)
# Out:
# Answer 8 = 70.0

# %%
# Question 9: Find the average of 120, 180 and 240
a = 120
b = 180
c = 240
print("Answer 9 =", (a + b + c) / 3)
# Out:
# Answer 9 = 180.0

# %%
# Question 10: Find the average of 90, 95 and 100
a = 90
b = 95
c = 100
print("Answer 10 =", (a + b + c) / 3)
# Out:
# Answer 10 = 95.0
